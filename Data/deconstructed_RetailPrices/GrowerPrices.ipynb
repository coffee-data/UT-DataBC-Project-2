# %%
import pandas as pd
import numpy as np
import os
import glob

# %% [markdown]
# # [ E ] xtract

# %%
path = '/Users/user/Desktop/D_Coffee_Data/ICO-Data-Project-Priv/data/deconstructed_RetailPrices/date_csvs' # use your path
all_files = glob.glob(os.path.join(path,"*.csv"))

# Sort the csv files by date
all_files.sort()

list_of_df = [pd.read_csv(d,header=4) for d in all_files]
df = pd.concat(list_of_df, ignore_index=True)

# %%
df
# Out:
#            Country     Continents    Currency_Type Type of Coffee  Jan-63  \
# 0              NaN            NaN              NaN            NaN     NaN
# 1              NaN            NaN              NaN            NaN     NaN
# 2          Burundi         Africa     (BIF/kg : P)        Arabica    20.0
# 3         Cameroon         Africa     (XAF/kg : G)        Robusta    90.3
# 4    Côte d'Ivoire         Africa     (XAF/kg : G)        Robusta    80.0
# ..             ...            ...              ...            ...     ...
# 648         Brazil  South America   (BRL/60kg : G)        Arabica     NaN
# 649         Brazil  South America   (BRL/60kg : G)        Robusta     NaN
# 650       Colombia  South America  (COP/125kg : P)        Arabica     NaN
# 651           Peru  South America     (PEN/kg : P)        Arabica     NaN
# 652            NaN            NaN              NaN            NaN     NaN
#
#      Feb-63  Mar-63  Apr-63  May-63  Jun-63  ...      Mar-18      Apr-18  \
# 0       NaN     NaN     NaN     NaN     NaN  ...         NaN         NaN
# 1       NaN     NaN     NaN     NaN     NaN  ...         NaN         NaN
# 2      20.0    20.0    20.5    20.5    20.5  ...         NaN         NaN
# 3      90.3    90.3    90.3    90.3    90.3  ...         NaN         NaN
# 4      80.0    80.0    80.0    80.0    80.0  ...         NaN         NaN
# ..      ...     ...     ...     ...     ...  ...         ...         ...
# 648     NaN     NaN     NaN     NaN     NaN  ...      429.82      430.71
# 649     NaN     NaN     NaN     NaN     NaN  ...      305.56      320.05
# 650     NaN     NaN     NaN     NaN     NaN  ...  729,854.84  714,440.48
# 651     NaN     NaN     NaN     NaN     NaN  ...         NaN         NaN
# 652     NaN     NaN     NaN     NaN     NaN  ...         NaN         NaN
#
#          May-18      Jun-18      Jul-18      Aug-18      Sep-18      Oct-18  \
# 0           NaN         NaN         NaN         NaN         NaN         NaN
# 1           NaN         NaN         NaN         NaN         NaN         NaN
# 2           NaN         NaN         NaN         NaN         NaN         NaN
# 3           NaN         NaN         NaN         NaN         NaN         NaN
# 4           NaN         NaN         NaN         NaN         NaN         NaN
# ..          ...         ...         ...         ...         ...         ...
# 648      451.02      452.52      439.25      421.16      415.39      441.23
# 649      330.79      335.39      332.39      319.26      319.38      331.71
# 650  753,978.00  745,380.95  717,045.45  685,000.00  684,210.53  793,130.43
# 651         NaN         NaN         NaN         NaN         NaN         NaN
# 652         NaN         NaN         NaN         NaN         NaN         NaN
#
#          Nov-18      Dec-18
# 0           NaN         NaN
# 1           NaN         NaN
# 2           NaN         NaN
# 3           NaN         NaN
# 4           NaN         NaN
# ..          ...         ...
# 648      441.59      420.32
# 649      332.33      309.44
# 650  802,928.57  726,825.00
# 651         NaN         NaN
# 652         NaN         NaN
#
# [653 rows x 628 columns]

# %% [markdown]
# # [ T ] ransform

# %%
# Quick preview
df.head()
# Out:
#          Country Continents Currency_Type Type of Coffee  Jan-63  Feb-63  \
# 0            NaN        NaN           NaN            NaN     NaN     NaN
# 1            NaN        NaN           NaN            NaN     NaN     NaN
# 2        Burundi     Africa  (BIF/kg : P)        Arabica    20.0    20.0
# 3       Cameroon     Africa  (XAF/kg : G)        Robusta    90.3    90.3
# 4  Côte d'Ivoire     Africa  (XAF/kg : G)        Robusta    80.0    80.0
#
#    Mar-63  Apr-63  May-63  Jun-63  ...  Mar-18  Apr-18  May-18  Jun-18  \
# 0     NaN     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN
# 1     NaN     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN
# 2    20.0    20.5    20.5    20.5  ...     NaN     NaN     NaN     NaN
# 3    90.3    90.3    90.3    90.3  ...     NaN     NaN     NaN     NaN
# 4    80.0    80.0    80.0    80.0  ...     NaN     NaN     NaN     NaN
#
#    Jul-18  Aug-18 Sep-18 Oct-18 Nov-18 Dec-18
# 0     NaN     NaN    NaN    NaN    NaN    NaN
# 1     NaN     NaN    NaN    NaN    NaN    NaN
# 2     NaN     NaN    NaN    NaN    NaN    NaN
# 3     NaN     NaN    NaN    NaN    NaN    NaN
# 4     NaN     NaN    NaN    NaN    NaN    NaN
#
# [5 rows x 628 columns]

# %%
# Check col headers
df.columns
# Out:
# Index(['Country', 'Continents', 'Currency_Type', 'Type of Coffee', 'Jan-63',
#        'Feb-63', 'Mar-63', 'Apr-63', 'May-63', 'Jun-63',
#        ...
#        'Mar-18', 'Apr-18', 'May-18', 'Jun-18', 'Jul-18', 'Aug-18', 'Sep-18',
#        'Oct-18', 'Nov-18', 'Dec-18'],
#       dtype='object', length=628)

# %%
# Check how many values per col
df.count()
# Out:
# Country           540
# Continents        540
# Currency_Type     540
# Type of Coffee    540
# Jan-63              8
#                  ...
# Aug-18             18
# Sep-18             16
# Oct-18             14
# Nov-18             17
# Dec-18             17
# Length: 628, dtype: int64

# %%
# Check data types
df.dtypes
# Out:
# Country            object
# Continents         object
# Currency_Type      object
# Type of Coffee     object
# Jan-63            float64
#                    ...
# Aug-18             object
# Sep-18             object
# Oct-18             object
# Nov-18             object
# Dec-18             object
# Length: 628, dtype: object

# %%
# Convert all values to float
cols = df.loc[:,'Jan-63':'Dec-18'].columns
df[cols] = df[cols].apply(pd.to_numeric, errors='coerce')

# %%
df.dtypes
# Out:
# Country            object
# Continents         object
# Currency_Type      object
# Type of Coffee     object
# Jan-63            float64
#                    ...
# Aug-18            float64
# Sep-18            float64
# Oct-18            float64
# Nov-18            float64
# Dec-18            float64
# Length: 628, dtype: object

# %%
# Check for missing index country values
df.isna().sum()
# Out:
# Country           113
# Continents        113
# Currency_Type     113
# Type of Coffee    113
# Jan-63            645
#                  ...
# Aug-18            644
# Sep-18            646
# Oct-18            648
# Nov-18            645
# Dec-18            645
# Length: 628, dtype: int64

# %%
# Remove those empty rows
df1 = df.dropna(subset=['Country'])
# # Recheck
df1.isna().sum()
# Out:
# Country             0
# Continents          0
# Currency_Type       0
# Type of Coffee      0
# Jan-63            532
#                  ...
# Aug-18            531
# Sep-18            533
# Oct-18            535
# Nov-18            532
# Dec-18            532
# Length: 628, dtype: int64

# %%
# Drop rows with completely missing data
df1 = df1.dropna(how='all')

# %%
df1
# Out:
#                               Country     Continents    Currency_Type  \
# 2                             Burundi         Africa     (BIF/kg : P)
# 3                            Cameroon         Africa     (XAF/kg : G)
# 4                       Côte d'Ivoire         Africa     (XAF/kg : G)
# 5                            Ethiopia         Africa   (ETB/17kg : G)
# 6                               Gabon         Africa     (XAF/kg : D)
# ..                                ...            ...              ...
# 647  Bolivia (Plurinational State of)  South America     (BOB/kg : G)
# 648                            Brazil  South America   (BRL/60kg : G)
# 649                            Brazil  South America   (BRL/60kg : G)
# 650                          Colombia  South America  (COP/125kg : P)
# 651                              Peru  South America     (PEN/kg : P)
#
#     Type of Coffee  Jan-63  Feb-63  Mar-63  Apr-63  May-63  Jun-63  ...  \
# 2          Arabica    20.0    20.0    20.0    20.5    20.5    20.5  ...
# 3          Robusta    90.3    90.3    90.3    90.3    90.3    90.3  ...
# 4          Robusta    80.0    80.0    80.0    80.0    80.0    80.0  ...
# 5          Arabica     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 6          Robusta     NaN     NaN     NaN     NaN     NaN     NaN  ...
# ..             ...     ...     ...     ...     ...     ...     ...  ...
# 647        Arabica     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 648        Arabica     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 649        Robusta     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 650        Arabica     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 651        Arabica     NaN     NaN     NaN     NaN     NaN     NaN  ...
#
#      Mar-18  Apr-18  May-18  Jun-18  Jul-18  Aug-18  Sep-18  Oct-18  Nov-18  \
# 2       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 5       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 6       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 647  101.55   38.43   31.06   36.06   46.28   38.98   37.15   67.33  105.78
# 648  429.82  430.71  451.02  452.52  439.25  421.16  415.39  441.23  441.59
# 649  305.56  320.05  330.79  335.39  332.39  319.26  319.38  331.71  332.33
# 650     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 651     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#      Dec-18
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
# 6       NaN
# ..      ...
# 647   83.62
# 648  420.32
# 649  309.44
# 650     NaN
# 651     NaN
#
# [540 rows x 628 columns]

# %%
# Iterate over currency and remove extraneous elements
def hasNumbers(inputString):
    return any(char.isdigit() for char in inputString)

s = df1['Currency_Type']

new_s = []
num = []
count = 0

for elt in s:
    elt = elt.replace('(',"")
    elt = elt.replace(')',"")
    elt = elt.replace('/'," ")
    elt = elt.replace(': ',"")
    
    if hasNumbers(elt):
        count += 1
        num.append(elt)
    else:
        num.append(elt.replace(elt,'nan'))
        
    new_s.append(elt)
    
df1['Currency_Type'] = new_s
df1.head()
# Out:
#          Country Continents Currency_Type Type of Coffee  Jan-63  Feb-63  \
# 2        Burundi     Africa      BIF kg P        Arabica    20.0    20.0
# 3       Cameroon     Africa      XAF kg G        Robusta    90.3    90.3
# 4  Côte d'Ivoire     Africa      XAF kg G        Robusta    80.0    80.0
# 5       Ethiopia     Africa    ETB 17kg G        Arabica     NaN     NaN
# 6          Gabon     Africa      XAF kg D        Robusta     NaN     NaN
#
#    Mar-63  Apr-63  May-63  Jun-63  ...  Mar-18  Apr-18  May-18  Jun-18  \
# 2    20.0    20.5    20.5    20.5  ...     NaN     NaN     NaN     NaN
# 3    90.3    90.3    90.3    90.3  ...     NaN     NaN     NaN     NaN
# 4    80.0    80.0    80.0    80.0  ...     NaN     NaN     NaN     NaN
# 5     NaN     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN
# 6     NaN     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN
#
#    Jul-18  Aug-18  Sep-18  Oct-18  Nov-18  Dec-18
# 2     NaN     NaN     NaN     NaN     NaN     NaN
# 3     NaN     NaN     NaN     NaN     NaN     NaN
# 4     NaN     NaN     NaN     NaN     NaN     NaN
# 5     NaN     NaN     NaN     NaN     NaN     NaN
# 6     NaN     NaN     NaN     NaN     NaN     NaN
#
# [5 rows x 628 columns]

# %%
df1[['Country_Code','Unit','Type', 'Blank']] = df1['Currency_Type'].str.split(' ',expand=True)

df1
# Out:
#                               Country     Continents Currency_Type  \
# 2                             Burundi         Africa      BIF kg P
# 3                            Cameroon         Africa      XAF kg G
# 4                       Côte d'Ivoire         Africa      XAF kg G
# 5                            Ethiopia         Africa    ETB 17kg G
# 6                               Gabon         Africa      XAF kg D
# ..                                ...            ...           ...
# 647  Bolivia (Plurinational State of)  South America      BOB kg G
# 648                            Brazil  South America    BRL 60kg G
# 649                            Brazil  South America    BRL 60kg G
# 650                          Colombia  South America   COP 125kg P
# 651                              Peru  South America      PEN kg P
#
#     Type of Coffee  Jan-63  Feb-63  Mar-63  Apr-63  May-63  Jun-63  ...  \
# 2          Arabica    20.0    20.0    20.0    20.5    20.5    20.5  ...
# 3          Robusta    90.3    90.3    90.3    90.3    90.3    90.3  ...
# 4          Robusta    80.0    80.0    80.0    80.0    80.0    80.0  ...
# 5          Arabica     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 6          Robusta     NaN     NaN     NaN     NaN     NaN     NaN  ...
# ..             ...     ...     ...     ...     ...     ...     ...  ...
# 647        Arabica     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 648        Arabica     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 649        Robusta     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 650        Arabica     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 651        Arabica     NaN     NaN     NaN     NaN     NaN     NaN  ...
#
#      Jul-18  Aug-18  Sep-18  Oct-18  Nov-18  Dec-18  Country_Code   Unit  \
# 2       NaN     NaN     NaN     NaN     NaN     NaN           BIF     kg
# 3       NaN     NaN     NaN     NaN     NaN     NaN           XAF     kg
# 4       NaN     NaN     NaN     NaN     NaN     NaN           XAF     kg
# 5       NaN     NaN     NaN     NaN     NaN     NaN           ETB   17kg
# 6       NaN     NaN     NaN     NaN     NaN     NaN           XAF     kg
# ..      ...     ...     ...     ...     ...     ...           ...    ...
# 647   46.28   38.98   37.15   67.33  105.78   83.62           BOB     kg
# 648  439.25  421.16  415.39  441.23  441.59  420.32           BRL   60kg
# 649  332.39  319.26  319.38  331.71  332.33  309.44           BRL   60kg
# 650     NaN     NaN     NaN     NaN     NaN     NaN           COP  125kg
# 651     NaN     NaN     NaN     NaN     NaN     NaN           PEN     kg
#
#      Type  Blank
# 2       P   None
# 3       G   None
# 4       G   None
# 5       G   None
# 6       D   None
# ..    ...    ...
# 647     G   None
# 648     G   None
# 649     G   None
# 650     P   None
# 651     P   None
#
# [540 rows x 632 columns]

# %%
cols = list(df1)

# move the column to head of list using index, pop and insert
cols.insert(3, cols.pop(cols.index('Type')))
cols.insert(3, cols.pop(cols.index('Unit')))
cols.insert(3, cols.pop(cols.index('Currency_Type')))
cols.insert(3, cols.pop(cols.index('Country_Code')))
df2 = df1.loc[:,cols]
df2['Currency_Type'] = df2['Currency_Type'].str.extract('(\d+)')
df2['Unit'] = df2['Unit'].str.extract('(\D+)')
df2.rename(columns={'Currency_Type':'Weight'}, inplace=True)
df2.drop(columns='Blank', inplace=True)
df2.fillna(value={'Weight':1}, inplace=True)

# %%
### Where I left off. Just completed getting everything cleaned up. Quick look over and should be able to
### start slicing

# %%
df2.reset_index(drop=True, inplace=True)

# %%
df2
# Out:
#                               Country     Continents Unit Country_Code Weight  \
# 0                             Burundi         Africa   kg          BIF      1
# 1                            Cameroon         Africa   kg          XAF      1
# 2                       Côte d'Ivoire         Africa   kg          XAF      1
# 3                            Ethiopia         Africa   kg          ETB     17
# 4                               Gabon         Africa   kg          XAF      1
# ..                                ...            ...  ...          ...    ...
# 535  Bolivia (Plurinational State of)  South America   kg          BOB      1
# 536                            Brazil  South America   kg          BRL     60
# 537                            Brazil  South America   kg          BRL     60
# 538                          Colombia  South America   kg          COP    125
# 539                              Peru  South America   kg          PEN      1
#
#     Type Type of Coffee  Jan-63  Feb-63  Mar-63  ...  Mar-18  Apr-18  May-18  \
# 0      P        Arabica    20.0    20.0    20.0  ...     NaN     NaN     NaN
# 1      G        Robusta    90.3    90.3    90.3  ...     NaN     NaN     NaN
# 2      G        Robusta    80.0    80.0    80.0  ...     NaN     NaN     NaN
# 3      G        Arabica     NaN     NaN     NaN  ...     NaN     NaN     NaN
# 4      D        Robusta     NaN     NaN     NaN  ...     NaN     NaN     NaN
# ..   ...            ...     ...     ...     ...  ...     ...     ...     ...
# 535    G        Arabica     NaN     NaN     NaN  ...  101.55   38.43   31.06
# 536    G        Arabica     NaN     NaN     NaN  ...  429.82  430.71  451.02
# 537    G        Robusta     NaN     NaN     NaN  ...  305.56  320.05  330.79
# 538    P        Arabica     NaN     NaN     NaN  ...     NaN     NaN     NaN
# 539    P        Arabica     NaN     NaN     NaN  ...     NaN     NaN     NaN
#
#      Jun-18  Jul-18  Aug-18  Sep-18  Oct-18  Nov-18  Dec-18
# 0       NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1       NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2       NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3       NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4       NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ..      ...     ...     ...     ...     ...     ...     ...
# 535   36.06   46.28   38.98   37.15   67.33  105.78   83.62
# 536  452.52  439.25  421.16  415.39  441.23  441.59  420.32
# 537  335.39  332.39  319.26  319.38  331.71  332.33  309.44
# 538     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 539     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# [540 rows x 631 columns]

# %%
lst_cols = []

for col in df2.loc[:,'Jan-63':].columns:
    if 'unnamed' not in col.lower():
        lst_cols.append(col)

# %%
# Clean up dates to remove issue of partial YY
s_dates = pd.Series(lst_cols)
s_dates_spl = s_dates.str.split("-",expand=True)

for i, elt in enumerate(s_dates_spl[1]):
    if int(elt) <= 99 and int(elt) > 18:
        s_dates_spl.at[i,1] = "19" + elt
    else:
        s_dates_spl.at[i,1] = "20" + elt
        
s_dates = s_dates_spl[0].str.cat(s_dates_spl[1], join='right', sep='-')

# %%
#  inplace replace col names to avoid date confusion on last digits
for i, col in enumerate(df2.loc[:,'Jan-63':].columns):
    df2.rename(columns={str(col) : str(s_dates[i])}, inplace = True)

# %%
df2.head()
# Out:
#          Country Continents Unit Country_Code Weight Type Type of Coffee  \
# 0        Burundi     Africa   kg          BIF      1    P        Arabica
# 1       Cameroon     Africa   kg          XAF      1    G        Robusta
# 2  Côte d'Ivoire     Africa   kg          XAF      1    G        Robusta
# 3       Ethiopia     Africa   kg          ETB     17    G        Arabica
# 4          Gabon     Africa   kg          XAF      1    D        Robusta
#
#    Jan-1963  Feb-1963  Mar-1963  ...  Mar-2018  Apr-2018  May-2018  Jun-2018  \
# 0      20.0      20.0      20.0  ...       NaN       NaN       NaN       NaN
# 1      90.3      90.3      90.3  ...       NaN       NaN       NaN       NaN
# 2      80.0      80.0      80.0  ...       NaN       NaN       NaN       NaN
# 3       NaN       NaN       NaN  ...       NaN       NaN       NaN       NaN
# 4       NaN       NaN       NaN  ...       NaN       NaN       NaN       NaN
#
#    Jul-2018  Aug-2018  Sep-2018  Oct-2018  Nov-2018  Dec-2018
# 0       NaN       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN       NaN
# 3       NaN       NaN       NaN       NaN       NaN       NaN
# 4       NaN       NaN       NaN       NaN       NaN       NaN
#
# [5 rows x 631 columns]

# %%
lst_cols = []

for col in df2.loc[:,'Jan-1963':].columns:
    if 'unnamed' not in col.lower():
        lst_cols.append(col)

# %%
df_test = pd.melt(df2, id_vars=['Country', 'Continents','Unit','Country_Code','Weight','Type of Coffee'], value_vars=lst_cols).rename(columns={'variable':'Date','value':'Price'})

# %%
df_test.sort_values('Country')
# Out:
#          Country Continents Unit Country_Code Weight Type of Coffee      Date  \
# 239439    Angola     Africa   kg          ANK      1        Robusta  Dec-2003
# 93586     Angola     Africa   kg          ANK      1        Robusta  Jun-1977
# 23248     Angola     Africa   kg          ANK      1        Robusta  Aug-1966
# 174390    Angola     Africa   kg          AOA      1        Robusta  Nov-1993
# 174389    Angola     Africa   kg          AOA      1        Arabica  Nov-1993
# ...          ...        ...  ...          ...    ...            ...       ...
# 48304   Zimbabwe     Africa    m          ZWD      1        Arabica  Jun-1970
# 235091  Zimbabwe     Africa    m          ZWD      1        Arabica  Apr-2003
# 48251   Zimbabwe     Africa    m          ZWD      1        Arabica  Jun-1970
# 210902  Zimbabwe     Africa    m          ZWD      1        Arabica  Jul-1999
# 10991   Zimbabwe     Africa    m          ZWD      1        Arabica  Sep-1964
#
#         Price
# 239439    NaN
# 93586     NaN
# 23248     NaN
# 174390    NaN
# 174389    NaN
# ...       ...
# 48304     NaN
# 235091    NaN
# 48251     NaN
# 210902    NaN
# 10991     NaN
#
# [336960 rows x 8 columns]

# %%
# .rename(columns=({'variable':'Date','value':'Price'}))

# %%
df_test.to_csv('test.csv')
