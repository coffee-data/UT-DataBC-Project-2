# %%
import pandas as pd
import numpy as np
import os
import glob

# %% [markdown]
# # [ E ] xtract

# %%
# Read xcel using pandas
path = '../GrowerPrices.xlsx'
xl = pd.read_excel(path, sheet_name = None)

# %%
# Combine rows igoring index
df = pd.concat(xl, ignore_index=True)

# %%
df
# Out:
#                            Unnamed: 0     Unnamed: 1       Unnamed: 2  \
# 0              Prices Paid to Growers            NaN              NaN
# 1                    in Current Terms            NaN              NaN
# 2                 (National Currency)            NaN              NaN
# 3                             Country            NaN   Type of Coffee
# 4                                 NaN            NaN              NaN
# ..                                ...            ...              ...
# 755  Bolivia (Plurinational State of)  South America     (BOB/kg : G)
# 756                            Brazil  South America   (BRL/60kg : G)
# 757                            Brazil  South America   (BRL/60kg : G)
# 758                          Colombia  South America  (COP/125kg : P)
# 759                              Peru  South America     (PEN/kg : P)
#
#     Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0          NaN        NaN        NaN        NaN        NaN        NaN
# 1          NaN        NaN        NaN        NaN        NaN        NaN
# 2          NaN        NaN        NaN        NaN        NaN        NaN
# 3       Jan-63     Feb-63     Mar-63     Apr-63     May-63     Jun-63
# 4          NaN        NaN        NaN        NaN        NaN        NaN
# ..         ...        ...        ...        ...        ...        ...
# 755    Arabica      44.13      55.37      35.88      26.45          0
# 756    Arabica     465.93     459.99      447.1     445.69     421.95
# 757    Robusta     283.29     299.58     303.44     295.88     290.33
# 758    Arabica     771788     721559     683972     685220     632156
# 759    Arabica       5.85       6.13       5.53       6.52        6.3
#
#     Unnamed: 9  ... Unnamed: 42 Unnamed: 43 Unnamed: 44 Unnamed: 45  \
# 0          NaN  ...         NaN         NaN         NaN         NaN
# 1          NaN  ...         NaN         NaN         NaN         NaN
# 2          NaN  ...         NaN         NaN         NaN         NaN
# 3       Jul-63  ...      Apr-66      May-66      Jun-66      Jul-66
# 4          NaN  ...         NaN         NaN         NaN         NaN
# ..         ...  ...         ...         ...         ...         ...
# 755       33.5  ...      101.55       38.43       31.06       36.06
# 756     424.02  ...      429.82      430.71      451.02      452.52
# 757     301.03  ...      305.56      320.05      330.79      335.39
# 758     671341  ...      729855      714440      753978      745381
# 759       6.48  ...         NaN         NaN         NaN         NaN
#
#     Unnamed: 46 Unnamed: 47 Unnamed: 48 Unnamed: 49 Unnamed: 50 Unnamed: 51
# 0           NaN         NaN         NaN         NaN         NaN         NaN
# 1           NaN         NaN         NaN         NaN         NaN         NaN
# 2           NaN         NaN         NaN         NaN         NaN         NaN
# 3        Aug-66      Sep-66      Oct-66      Nov-66      Dec-66         NaN
# 4           NaN         NaN         NaN         NaN         NaN         NaN
# ..          ...         ...         ...         ...         ...         ...
# 755       46.28       38.98       37.15       67.33      105.78       83.62
# 756      439.25      421.16      415.39      441.23      441.59      420.32
# 757      332.39      319.26      319.38      331.71      332.33      309.44
# 758      717045      685000      684211      793130      802929      726825
# 759         NaN         NaN         NaN         NaN         NaN         NaN
#
# [760 rows x 52 columns]

# %% [markdown]
# # [ T ] ransform

# %%
# Quick preview
df.head()
# Out:
#          Country Continents Currency_Type Type of Coffee  Jan-63  Feb-63  \
# 0            NaN        NaN           NaN            NaN     NaN     NaN
# 1            NaN        NaN           NaN            NaN     NaN     NaN
# 2        Burundi     Africa  (BIF/kg : P)        Arabica    20.0    20.0
# 3       Cameroon     Africa  (XAF/kg : G)        Robusta    90.3    90.3
# 4  Côte d'Ivoire     Africa  (XAF/kg : G)        Robusta    80.0    80.0
#
#    Mar-63  Apr-63  May-63  Jun-63  ...  Mar-18  Apr-18  May-18  Jun-18  \
# 0     NaN     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN
# 1     NaN     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN
# 2    20.0    20.5    20.5    20.5  ...     NaN     NaN     NaN     NaN
# 3    90.3    90.3    90.3    90.3  ...     NaN     NaN     NaN     NaN
# 4    80.0    80.0    80.0    80.0  ...     NaN     NaN     NaN     NaN
#
#    Jul-18  Aug-18 Sep-18 Oct-18 Nov-18 Dec-18
# 0     NaN     NaN    NaN    NaN    NaN    NaN
# 1     NaN     NaN    NaN    NaN    NaN    NaN
# 2     NaN     NaN    NaN    NaN    NaN    NaN
# 3     NaN     NaN    NaN    NaN    NaN    NaN
# 4     NaN     NaN    NaN    NaN    NaN    NaN
#
# [5 rows x 628 columns]

# %%
# Check col headers
df.columns
# Out:
# Index(['Country', 'Continents', 'Currency_Type', 'Type of Coffee', 'Jan-63',
#        'Feb-63', 'Mar-63', 'Apr-63', 'May-63', 'Jun-63',
#        ...
#        'Mar-18', 'Apr-18', 'May-18', 'Jun-18', 'Jul-18', 'Aug-18', 'Sep-18',
#        'Oct-18', 'Nov-18', 'Dec-18'],
#       dtype='object', length=628)

# %%
# Check how many values per col
df.count()
# Out:
# Country           540
# Continents        540
# Currency_Type     540
# Type of Coffee    540
# Jan-63              8
#                  ...
# Aug-18             18
# Sep-18             16
# Oct-18             14
# Nov-18             17
# Dec-18             17
# Length: 628, dtype: int64

# %%
# Check data types
df.dtypes
# Out:
# Country            object
# Continents         object
# Currency_Type      object
# Type of Coffee     object
# Jan-63            float64
#                    ...
# Aug-18             object
# Sep-18             object
# Oct-18             object
# Nov-18             object
# Dec-18             object
# Length: 628, dtype: object

# %%
# Convert all values to float
cols = df.loc[:,'Jan-63':'Dec-18'].columns
df[cols] = df[cols].apply(pd.to_numeric, errors='coerce')

# %%
df.dtypes
# Out:
# Country            object
# Continents         object
# Currency_Type      object
# Type of Coffee     object
# Jan-63            float64
#                    ...
# Aug-18            float64
# Sep-18            float64
# Oct-18            float64
# Nov-18            float64
# Dec-18            float64
# Length: 628, dtype: object

# %%
# Check for missing index country values
df.isna().sum()
# Out:
# Country           113
# Continents        113
# Currency_Type     113
# Type of Coffee    113
# Jan-63            645
#                  ...
# Aug-18            644
# Sep-18            646
# Oct-18            648
# Nov-18            645
# Dec-18            645
# Length: 628, dtype: int64

# %%
# Remove those empty rows
df1 = df.dropna(subset=['Country'])
# # Recheck
df1.isna().sum()
# Out:
# Country             0
# Continents          0
# Currency_Type       0
# Type of Coffee      0
# Jan-63            532
#                  ...
# Aug-18            531
# Sep-18            533
# Oct-18            535
# Nov-18            532
# Dec-18            532
# Length: 628, dtype: int64

# %%
# Drop rows with completely missing data
df1 = df1.dropna(how='all')

# %%
df1
# Out:
#                               Country     Continents    Currency_Type  \
# 2                             Burundi         Africa     (BIF/kg : P)
# 3                            Cameroon         Africa     (XAF/kg : G)
# 4                       Côte d'Ivoire         Africa     (XAF/kg : G)
# 5                            Ethiopia         Africa   (ETB/17kg : G)
# 6                               Gabon         Africa     (XAF/kg : D)
# ..                                ...            ...              ...
# 647  Bolivia (Plurinational State of)  South America     (BOB/kg : G)
# 648                            Brazil  South America   (BRL/60kg : G)
# 649                            Brazil  South America   (BRL/60kg : G)
# 650                          Colombia  South America  (COP/125kg : P)
# 651                              Peru  South America     (PEN/kg : P)
#
#     Type of Coffee  Jan-63  Feb-63  Mar-63  Apr-63  May-63  Jun-63  ...  \
# 2          Arabica    20.0    20.0    20.0    20.5    20.5    20.5  ...
# 3          Robusta    90.3    90.3    90.3    90.3    90.3    90.3  ...
# 4          Robusta    80.0    80.0    80.0    80.0    80.0    80.0  ...
# 5          Arabica     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 6          Robusta     NaN     NaN     NaN     NaN     NaN     NaN  ...
# ..             ...     ...     ...     ...     ...     ...     ...  ...
# 647        Arabica     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 648        Arabica     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 649        Robusta     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 650        Arabica     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 651        Arabica     NaN     NaN     NaN     NaN     NaN     NaN  ...
#
#      Mar-18  Apr-18  May-18  Jun-18  Jul-18  Aug-18  Sep-18  Oct-18  Nov-18  \
# 2       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 5       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 6       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 647  101.55   38.43   31.06   36.06   46.28   38.98   37.15   67.33  105.78
# 648  429.82  430.71  451.02  452.52  439.25  421.16  415.39  441.23  441.59
# 649  305.56  320.05  330.79  335.39  332.39  319.26  319.38  331.71  332.33
# 650     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 651     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#      Dec-18
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
# 6       NaN
# ..      ...
# 647   83.62
# 648  420.32
# 649  309.44
# 650     NaN
# 651     NaN
#
# [540 rows x 628 columns]

# %%
# Iterate over currency and remove extraneous elements
def hasNumbers(inputString):
    return any(char.isdigit() for char in inputString)

s = df1['Currency_Type']

new_s = []
num = []
count = 0

for elt in s:
    elt = elt.replace('(',"")
    elt = elt.replace(')',"")
    elt = elt.replace('/'," ")
    elt = elt.replace(': ',"")
    
    if hasNumbers(elt):
        count += 1
        num.append(elt)
    else:
        num.append(elt.replace(elt,'nan'))
        
    new_s.append(elt)
    
df1['Currency_Type'] = new_s
df1.head()
# Out:
#          Country Continents Currency_Type Type of Coffee  Jan-63  Feb-63  \
# 2        Burundi     Africa      BIF kg P        Arabica    20.0    20.0
# 3       Cameroon     Africa      XAF kg G        Robusta    90.3    90.3
# 4  Côte d'Ivoire     Africa      XAF kg G        Robusta    80.0    80.0
# 5       Ethiopia     Africa    ETB 17kg G        Arabica     NaN     NaN
# 6          Gabon     Africa      XAF kg D        Robusta     NaN     NaN
#
#    Mar-63  Apr-63  May-63  Jun-63  ...  Mar-18  Apr-18  May-18  Jun-18  \
# 2    20.0    20.5    20.5    20.5  ...     NaN     NaN     NaN     NaN
# 3    90.3    90.3    90.3    90.3  ...     NaN     NaN     NaN     NaN
# 4    80.0    80.0    80.0    80.0  ...     NaN     NaN     NaN     NaN
# 5     NaN     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN
# 6     NaN     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN
#
#    Jul-18  Aug-18  Sep-18  Oct-18  Nov-18  Dec-18
# 2     NaN     NaN     NaN     NaN     NaN     NaN
# 3     NaN     NaN     NaN     NaN     NaN     NaN
# 4     NaN     NaN     NaN     NaN     NaN     NaN
# 5     NaN     NaN     NaN     NaN     NaN     NaN
# 6     NaN     NaN     NaN     NaN     NaN     NaN
#
# [5 rows x 628 columns]

# %%
df1[['Country_Code','Unit','Type', 'Blank']] = df1['Currency_Type'].str.split(' ',expand=True)

df1.head(50)
# Out:
#                          Country                Continents Currency_Type  \
# 2                        Burundi                    Africa      BIF kg P
# 3                       Cameroon                    Africa      XAF kg G
# 4                  Côte d'Ivoire                    Africa      XAF kg G
# 5                       Ethiopia                    Africa    ETB 17kg G
# 6                          Gabon                    Africa      XAF kg D
# 7                          Kenya                    Africa    KES 50kg G
# 8                     Madagascar                    Africa      MGF kg G
# 9                           Togo                    Africa      XAF kg G
# 12                    Costa Rica  Central America & Mexico      CRC SQ G
# 13                     Guatemala  Central America & Mexico      GTQ SQ G
# 16                        Brazil             South America    CRZ 60kg G
# 17                      Colombia             South America   COP 125kg P
# 18                     Venezuela             South America      VEB SQ G
# 22                       Burundi                    Africa      BIF kg P
# 23                      Cameroon                    Africa      XAF kg G
# 24                 Côte d'Ivoire                    Africa      XAF kg G
# 25                      Ethiopia                    Africa    ETB 17kg G
# 26                         Gabon                    Africa      XAF kg D
# 27                         Kenya                    Africa    KES 50kg G
# 28                    Madagascar                    Africa      MGF kg G
# 29                          Togo                    Africa      XAF kg G
# 30                        Uganda                    Africa      UGS kg G
# 33                    Costa Rica  Central America & Mexico      CRC SQ G
# 34                          Cuba  Central America & Mexico    CUP 28lb F
# 35                     Guatemala  Central America & Mexico      GTQ SQ G
# 38                        Brazil             South America    CRZ 60kg G
# 39                      Colombia             South America   COP 125kg P
# 40                     Venezuela             South America      VEB SQ G
# 44                        Angola                    Africa      ANK kg D
# 45                         Benin                    Africa      XAF kg G
# 46                       Burundi                    Africa      BIF kg P
# 47                      Cameroon                    Africa      XAF kg G
# 48      Central African Republic                    Africa      XAF kg G
# 49                         Congo                    Africa      XAF kg G
# 50                 Côte d'Ivoire                    Africa      XAF kg G
# 51  Democratic Republic of Congo                    Africa      ZAA kg P
# 52                      Ethiopia                    Africa    ETB 17kg G
# 53                         Gabon                    Africa      XAF kg D
# 54                         Ghana                    Africa    GHC 60kg G
# 55                        Guinea                    Africa      GNF kg G
# 56                         Kenya                    Africa    KES 50kg G
# 57                       Liberia                    Africa          LRD
# 58                    Madagascar                    Africa      MGF kg G
# 59                       Nigeria                    Africa   NGN m Ton G
# 60                        Rwanda                    Africa      RWF kg P
# 61                  Sierra Leone                    Africa   SLL L Ton G
# 62                      Tanzania                    Africa      TZS kg P
# 63                          Togo                    Africa      XAF kg G
# 64                        Uganda                    Africa      UGS kg G
# 65                        Uganda                    Africa      UGS kg G
#
#    Type of Coffee  Jan-63  Feb-63  Mar-63  Apr-63  May-63  Jun-63  ...  \
# 2         Arabica   20.00   20.00   20.00   20.50   20.50   20.50  ...
# 3         Robusta   90.30   90.30   90.30   90.30   90.30   90.30  ...
# 4         Robusta   80.00   80.00   80.00   80.00   80.00   80.00  ...
# 5         Arabica     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 6         Robusta     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 7         Arabica  274.00  274.00  274.00  274.00  274.00  274.00  ...
# 8         Robusta   83.00   83.00   83.00   83.00   83.00   83.00  ...
# 9         Robusta   65.00   65.00   65.00   65.00   65.00   65.00  ...
# 12        Arabica  229.22  229.22  229.22  229.22  229.22  229.22  ...
# 13        Arabica     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 16        Arabica     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 17        Arabica  555.52  555.52  555.52  555.52  555.52  555.52  ...
# 18        Arabica     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 22        Arabica     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 23        Robusta     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 24        Robusta     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 25        Arabica     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 26        Robusta     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 27        Arabica     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 28        Robusta     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 29        Robusta     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 30        Arabica     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 33        Arabica     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 34        Arabica     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 35        Arabica     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 38        Arabica     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 39        Arabica     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 40        Arabica     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 44        Robusta     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 45        Robusta     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 46        Arabica     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 47        Robusta     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 48        Robusta     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 49        Robusta     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 50        Robusta     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 51        Robusta     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 52        Arabica     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 53        Robusta     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 54        Robusta     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 55        Robusta     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 56        Arabica     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 57        Robusta     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 58        Robusta     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 59        Robusta     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 60        Arabica     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 61        Robusta     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 62        Arabica     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 63        Robusta     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 64        Arabica     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 65        Robusta     NaN     NaN     NaN     NaN     NaN     NaN  ...
#
#     Jul-18  Aug-18  Sep-18  Oct-18  Nov-18  Dec-18  Country_Code   Unit  Type  \
# 2      NaN     NaN     NaN     NaN     NaN     NaN           BIF     kg     P
# 3      NaN     NaN     NaN     NaN     NaN     NaN           XAF     kg     G
# 4      NaN     NaN     NaN     NaN     NaN     NaN           XAF     kg     G
# 5      NaN     NaN     NaN     NaN     NaN     NaN           ETB   17kg     G
# 6      NaN     NaN     NaN     NaN     NaN     NaN           XAF     kg     D
# 7      NaN     NaN     NaN     NaN     NaN     NaN           KES   50kg     G
# 8      NaN     NaN     NaN     NaN     NaN     NaN           MGF     kg     G
# 9      NaN     NaN     NaN     NaN     NaN     NaN           XAF     kg     G
# 12     NaN     NaN     NaN     NaN     NaN     NaN           CRC     SQ     G
# 13     NaN     NaN     NaN     NaN     NaN     NaN           GTQ     SQ     G
# 16     NaN     NaN     NaN     NaN     NaN     NaN           CRZ   60kg     G
# 17     NaN     NaN     NaN     NaN     NaN     NaN           COP  125kg     P
# 18     NaN     NaN     NaN     NaN     NaN     NaN           VEB     SQ     G
# 22     NaN     NaN     NaN     NaN     NaN     NaN           BIF     kg     P
# 23     NaN     NaN     NaN     NaN     NaN     NaN           XAF     kg     G
# 24     NaN     NaN     NaN     NaN     NaN     NaN           XAF     kg     G
# 25     NaN     NaN     NaN     NaN     NaN     NaN           ETB   17kg     G
# 26     NaN     NaN     NaN     NaN     NaN     NaN           XAF     kg     D
# 27     NaN     NaN     NaN     NaN     NaN     NaN           KES   50kg     G
# 28     NaN     NaN     NaN     NaN     NaN     NaN           MGF     kg     G
# 29     NaN     NaN     NaN     NaN     NaN     NaN           XAF     kg     G
# 30     NaN     NaN     NaN     NaN     NaN     NaN           UGS     kg     G
# 33     NaN     NaN     NaN     NaN     NaN     NaN           CRC     SQ     G
# 34     NaN     NaN     NaN     NaN     NaN     NaN           CUP   28lb     F
# 35     NaN     NaN     NaN     NaN     NaN     NaN           GTQ     SQ     G
# 38     NaN     NaN     NaN     NaN     NaN     NaN           CRZ   60kg     G
# 39     NaN     NaN     NaN     NaN     NaN     NaN           COP  125kg     P
# 40     NaN     NaN     NaN     NaN     NaN     NaN           VEB     SQ     G
# 44     NaN     NaN     NaN     NaN     NaN     NaN           ANK     kg     D
# 45     NaN     NaN     NaN     NaN     NaN     NaN           XAF     kg     G
# 46     NaN     NaN     NaN     NaN     NaN     NaN           BIF     kg     P
# 47     NaN     NaN     NaN     NaN     NaN     NaN           XAF     kg     G
# 48     NaN     NaN     NaN     NaN     NaN     NaN           XAF     kg     G
# 49     NaN     NaN     NaN     NaN     NaN     NaN           XAF     kg     G
# 50     NaN     NaN     NaN     NaN     NaN     NaN           XAF     kg     G
# 51     NaN     NaN     NaN     NaN     NaN     NaN           ZAA     kg     P
# 52     NaN     NaN     NaN     NaN     NaN     NaN           ETB   17kg     G
# 53     NaN     NaN     NaN     NaN     NaN     NaN           XAF     kg     D
# 54     NaN     NaN     NaN     NaN     NaN     NaN           GHC   60kg     G
# 55     NaN     NaN     NaN     NaN     NaN     NaN           GNF     kg     G
# 56     NaN     NaN     NaN     NaN     NaN     NaN           KES   50kg     G
# 57     NaN     NaN     NaN     NaN     NaN     NaN           LRD         None
# 58     NaN     NaN     NaN     NaN     NaN     NaN           MGF     kg     G
# 59     NaN     NaN     NaN     NaN     NaN     NaN           NGN      m   Ton
# 60     NaN     NaN     NaN     NaN     NaN     NaN           RWF     kg     P
# 61     NaN     NaN     NaN     NaN     NaN     NaN           SLL      L   Ton
# 62     NaN     NaN     NaN     NaN     NaN     NaN           TZS     kg     P
# 63     NaN     NaN     NaN     NaN     NaN     NaN           XAF     kg     G
# 64     NaN     NaN     NaN     NaN     NaN     NaN           UGS     kg     G
# 65     NaN     NaN     NaN     NaN     NaN     NaN           UGS     kg     G
#
#     Blank
# 2    None
# 3    None
# 4    None
# 5    None
# 6    None
# 7    None
# 8    None
# 9    None
# 12   None
# 13   None
# 16   None
# 17   None
# 18   None
# 22   None
# 23   None
# 24   None
# 25   None
# 26   None
# 27   None
# 28   None
# 29   None
# 30   None
# 33   None
# 34   None
# 35   None
# 38   None
# 39   None
# 40   None
# 44   None
# 45   None
# 46   None
# 47   None
# 48   None
# 49   None
# 50   None
# 51   None
# 52   None
# 53   None
# 54   None
# 55   None
# 56   None
# 57   None
# 58   None
# 59      G
# 60   None
# 61      G
# 62   None
# 63   None
# 64   None
# 65   None
#
# [50 rows x 632 columns]

# %%
cols = list(df1)

# move the column to head of list using index, pop and insert
cols.insert(3, cols.pop(cols.index('Type')))
cols.insert(3, cols.pop(cols.index('Unit')))
cols.insert(3, cols.pop(cols.index('Currency_Type')))
cols.insert(3, cols.pop(cols.index('Country_Code')))
df2 = df1.loc[:,cols]
df2['Currency_Type'] = df2['Currency_Type'].str.extract('(\d+)')
df2['Unit'] = df2['Unit'].str.extract('(\D+)')
df2.rename(columns={'Currency_Type':'Weight'}, inplace=True)
df2.drop(columns='Blank', inplace=True)
df2.fillna(value={'Weight':1}, inplace=True)

# %%
### Where I left off. Just completed getting everything cleaned up. Quick look over and should be able to
### start slicing

# %%
df2.reset_index(drop=True, inplace=True)

# %%
df2
# Out:
#                               Country     Continents Unit Country_Code Weight  \
# 0                             Burundi         Africa   kg          BIF      1
# 1                            Cameroon         Africa   kg          XAF      1
# 2                       Côte d'Ivoire         Africa   kg          XAF      1
# 3                            Ethiopia         Africa   kg          ETB     17
# 4                               Gabon         Africa   kg          XAF      1
# ..                                ...            ...  ...          ...    ...
# 535  Bolivia (Plurinational State of)  South America   kg          BOB      1
# 536                            Brazil  South America   kg          BRL     60
# 537                            Brazil  South America   kg          BRL     60
# 538                          Colombia  South America   kg          COP    125
# 539                              Peru  South America   kg          PEN      1
#
#     Type Type of Coffee  Jan-1963  Feb-1963  Mar-1963  ...  Mar-2018  \
# 0      P        Arabica      20.0      20.0      20.0  ...       NaN
# 1      G        Robusta      90.3      90.3      90.3  ...       NaN
# 2      G        Robusta      80.0      80.0      80.0  ...       NaN
# 3      G        Arabica       NaN       NaN       NaN  ...       NaN
# 4      D        Robusta       NaN       NaN       NaN  ...       NaN
# ..   ...            ...       ...       ...       ...  ...       ...
# 535    G        Arabica       NaN       NaN       NaN  ...    101.55
# 536    G        Arabica       NaN       NaN       NaN  ...    429.82
# 537    G        Robusta       NaN       NaN       NaN  ...    305.56
# 538    P        Arabica       NaN       NaN       NaN  ...       NaN
# 539    P        Arabica       NaN       NaN       NaN  ...       NaN
#
#      Apr-2018  May-2018  Jun-2018  Jul-2018  Aug-2018  Sep-2018  Oct-2018  \
# 0         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# ..        ...       ...       ...       ...       ...       ...       ...
# 535     38.43     31.06     36.06     46.28     38.98     37.15     67.33
# 536    430.71    451.02    452.52    439.25    421.16    415.39    441.23
# 537    320.05    330.79    335.39    332.39    319.26    319.38    331.71
# 538       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 539       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#      Nov-2018  Dec-2018
# 0         NaN       NaN
# 1         NaN       NaN
# 2         NaN       NaN
# 3         NaN       NaN
# 4         NaN       NaN
# ..        ...       ...
# 535    105.78     83.62
# 536    441.59    420.32
# 537    332.33    309.44
# 538       NaN       NaN
# 539       NaN       NaN
#
# [540 rows x 631 columns]

# %%
lst_cols = []

for col in df2.loc[:,'Jan-63':].columns:
    if 'unnamed' not in col.lower():
        lst_cols.append(col)

# %%
# Clean up dates to remove issue of partial YY
s_dates = pd.Series(lst_cols)
s_dates_spl = s_dates.str.split("-",expand=True)

for i, elt in enumerate(s_dates_spl[1]):
    if int(elt) <= 99 and int(elt) > 18:
        s_dates_spl.at[i,1] = "19" + elt
    else:
        s_dates_spl.at[i,1] = "20" + elt
        
s_dates = s_dates_spl[0].str.cat(s_dates_spl[1], join='right', sep='-')

# %%
#  inplace replace col names to avoid date confusion on last digits
for i, col in enumerate(df2.loc[:,'Jan-63':].columns):
    df2.rename(columns={str(col) : str(s_dates[i])}, inplace = True)

# %%
df2.head()
# Out:
#          Country Continents Unit Country_Code Weight Type Type of Coffee  \
# 0        Burundi     Africa   kg          BIF      1    P        Arabica
# 1       Cameroon     Africa   kg          XAF      1    G        Robusta
# 2  Côte d'Ivoire     Africa   kg          XAF      1    G        Robusta
# 3       Ethiopia     Africa   kg          ETB     17    G        Arabica
# 4          Gabon     Africa   kg          XAF      1    D        Robusta
#
#    Jan-1963  Feb-1963  Mar-1963  ...  Mar-2018  Apr-2018  May-2018  Jun-2018  \
# 0      20.0      20.0      20.0  ...       NaN       NaN       NaN       NaN
# 1      90.3      90.3      90.3  ...       NaN       NaN       NaN       NaN
# 2      80.0      80.0      80.0  ...       NaN       NaN       NaN       NaN
# 3       NaN       NaN       NaN  ...       NaN       NaN       NaN       NaN
# 4       NaN       NaN       NaN  ...       NaN       NaN       NaN       NaN
#
#    Jul-2018  Aug-2018  Sep-2018  Oct-2018  Nov-2018  Dec-2018
# 0       NaN       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN       NaN
# 3       NaN       NaN       NaN       NaN       NaN       NaN
# 4       NaN       NaN       NaN       NaN       NaN       NaN
#
# [5 rows x 631 columns]

# %%
lst_cols = []

for col in df2.loc[:,'Jan-1963':].columns:
    if 'unnamed' not in col.lower():
        lst_cols.append(col)

# %%
df_test = pd.melt(df2, id_vars=['Country', 'Continents','Unit','Country_Code','Weight','Type','Type of Coffee'], value_vars=lst_cols).rename(columns={'variable':'Date','value':'Price'})

# %%
df_test.sort_values('Country')
# Out:
#          Country Continents Unit Country_Code Weight Type Type of Coffee  \
# 239439    Angola     Africa   kg          ANK      1    D        Robusta
# 93586     Angola     Africa   kg          ANK      1    D        Robusta
# 23248     Angola     Africa   kg          ANK      1    D        Robusta
# 174390    Angola     Africa   kg          AOA      1    D        Robusta
# 174389    Angola     Africa   kg          AOA      1    D        Arabica
# ...          ...        ...  ...          ...    ...  ...            ...
# 48304   Zimbabwe     Africa    m          ZWD      1  Ton        Arabica
# 235091  Zimbabwe     Africa    m          ZWD      1  Ton        Arabica
# 48251   Zimbabwe     Africa    m          ZWD      1  Ton        Arabica
# 210902  Zimbabwe     Africa    m          ZWD      1  Ton        Arabica
# 10991   Zimbabwe     Africa    m          ZWD      1  Ton        Arabica
#
#             Date  Price
# 239439  Dec-2003    NaN
# 93586   Jun-1977    NaN
# 23248   Aug-1966    NaN
# 174390  Nov-1993    NaN
# 174389  Nov-1993    NaN
# ...          ...    ...
# 48304   Jun-1970    NaN
# 235091  Apr-2003    NaN
# 48251   Jun-1970    NaN
# 210902  Jul-1999    NaN
# 10991   Sep-1964    NaN
#
# [336960 rows x 9 columns]

# %%
# .rename(columns=({'variable':'Date','value':'Price'}))

# %%
df_test.to_csv('GrowerPrices_CLEANED.csv')

# %%
# df_test[df_test['Date'] == 'Dec-1989']
# Out:
# Empty DataFrame
# Columns: [Country, Continents, Unit, Country_Code, Weight, Type, Type of Coffee, Date, Price]
# Index: []
